# %% [markdown]
# <a href="https://colab.research.google.com/github/fazal357/AI-Accident-Detection-Using-YOLOv8/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Jan 29 17:32:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 918, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {list(MODES)}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=checks'. Valid modes are ['benchmark', 'track', 'val', 'export', 'predict', 'train'].
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
# ...

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode= predict model = yolov8n.pt conf=0.25 source="/content/cars2.jpg"
# Out:
# /content
# ...
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/cars2.jpg: 640x384 18 cars, 2 buss, 1 truck, 75.4ms
# Speed: 13.5ms preprocess, 75.4ms inference, 38.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename ='/content/runs/detect/predict/cars2.jpg', height = 600)
# Out:
# /content
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2968198325.py in <cell line: 0>()
#       1 get_ipython().run_line_magic('cd', '{HOME}')
# ----> 2 Image(filename ='/content/runs/detect/predict/cars2.jpg', height = 600)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
# ...

# %%
# %cd {HOME}

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="Zcbwo2q87eX4yG1MAKci")
project = rf.workspace("pappu-panda").project("road-accident-2vton")
version = project.version(3)
dataset = version.download("yolov8-obb")
# Out:
# /content
# loading Roboflow workspace...
# loading Roboflow project...
# Generating version still in progress. Progress: 100.0%
# ...
# Extracting Dataset Version Zip to Road-Accident-3 in yolov8-obb:: 100%|██████████| 17922/17922 [00:08<00:00, 2145.40it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode= val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 930, in entrypoint
#     raise ValueError(f"Invalid 'task={task}'. Valid tasks are {list(TASKS)}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'task=tect'. Valid tasks are ['segment', 'classify', 'obb', 'detect', 'pose'].
#
#     Arguments received: ['yolo', 'task=tect', 'mode=', 'val', 'model=/content/runs/detect/train/weights/best.pt', 'data=/content/Road-Accident-3/data.yaml']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['segment', 'classify', 'obb', 'detect', 'pose']
#                 MODE (required) is one of ['val', 'train', 'track', 'predict', 'export', 'benchmark']
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=25 imgsz=800
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.4.9 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.40 source =/content/accident_video.mp4
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/2298) /content/accident_video.mp4: 480x800 (no detections), 45.9ms
# video 1/1 (frame 2/2298) /content/accident_video.mp4: 480x800 (no detections), 7.1ms
# video 1/1 (frame 3/2298) /content/accident_video.mp4: 480x800 (no detections), 7.1ms
# video 1/1 (frame 4/2298) /content/accident_video.mp4: 480x800 (no detections), 7.1ms
# video 1/1 (frame 5/2298) /content/accident_video.mp4: 480x800 (no detections), 7.1ms
# video 1/1 (frame 6/2298) /content/accident_video.mp4: 480x800 (no detections), 7.1ms
# video 1/1 (frame 7/2298) /content/accident_video.mp4: 480x800 (no detections), 7.1ms
# video 1/1 (frame 8/2298) /content/accident_video.mp4: 480x800 (no detections), 7.1ms
# video 1/1 (frame 9/2298) /content/accident_video.mp4: 480x800 (no detections), 7.1ms
# ...

# %%
# !zip -r /content/.zip /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/Road-Accident-2/train/labels/_93177601_mediaitem93177600_jpg.rf.e3b863e571da6a75b96d6d598f661a56.txt (deflated 58%)
#   adding: content/Road-Accident-2/train/labels/IMG_2767-scaled-e1723748213479_jpg.rf.5fcc290e8f9e0bc3104427861a7df996.txt (deflated 62%)
#   adding: content/Road-Accident-2/train/labels/download-16-_jpeg.rf.56cdf9876a3a201d8a5a38502053cd95.txt (deflated 23%)
#   adding: content/Road-Accident-2/train/labels/prothomalo-english_2022-07_ae9d3d44-1248-4fb8-a640-e5ca3d358e71_prothomalo_bangla_2022_07_fc9d169a_86f5_44a7_9160_88aa34849404_Bogura_DH0611_20220716_IMG_20220716_W_jpg.rf.90f4ed5297f045dfdc30b170cf5640d6.txt (deflated 28%)
#   adding: content/Road-Accident-2/train/labels/download-10-_jpeg.rf.e685f810710c7290b498d95f37fc54ed.txt (deflated 39%)
#   adding: content/Road-Accident-2/train/labels/What-You-Should-Know-About-Truck-Accidents-2_jpg.rf.e6a3f7fe0ee9726d3cf3d4928be443e1.txt (deflated 62%)
# ...

# %%
# !zip -r /content/.zip /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/Road-Accident-2/train/labels/download-18-_jpeg.rf.1123d671ef70ec072d79627b1dcaaf32.txt (deflated 62%)
#   adding: content/Road-Accident-2/train/labels/13-killed-dozens-injured-in-ivory-coast-road-accident-1725741900714_jpg.rf.bcea3511ffba6ca21b0fad3dc47ba16c.txt (deflated 30%)
#   adding: content/Road-Accident-2/train/labels/download-38-_png.rf.a09bba2a5dd322e11fb66b5ae6ee6fa6.txt (stored 0%)
#   adding: content/Road-Accident-2/train/labels/nighttime-car-crash-stockcake_jpg.rf.e0d5384c72fc0b2ee8326f7576d6f89d.txt (deflated 59%)
#   adding: content/Road-Accident-2/train/labels/WEb_sUMMER_Fatal_jpg.rf.023cd6ff3a0a8833a2d4181235b123d9.txt (deflated 56%)
#   adding: content/Road-Accident-2/train/labels/images_blog_car-accident_jpg.rf.429b06c1e00405a8bd587534de60dc35.txt (deflated 47%)
#   adding: content/Road-Accident-2/train/labels/images-3-_jpeg.rf.4dbf22265d04073e4ffd34d1e3a50f51.txt (deflated 60%)
# ...
